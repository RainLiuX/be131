# %%
import sqlite3

# connect database
conn = sqlite3.connect('lab4.db')
c = conn.cursor()
with conn:
    c.execute("DROP TABLE IF EXISTS genes;")
    c.execute("DROP TABLE IF EXISTS ensymes;")
    c.execute("DROP TABLE IF EXISTS pathways;")

# %%
import sqlite3

# connect database
conn = sqlite3.connect('lab4.db')
c = conn.cursor()

# create tables: gene, pathway, enzyme
c.execute("""CREATE TABLE IF NOT EXISTS genes (id INTEGER PRIMARY KEY AUTOINCREMENT,
                                name TEXT,
                                description TEXT,
                                organism TEXT,
                                nt_seq TEXT,
                                chromosome TEXT,
                                tran_seq TEXT)""")
c.execute("""CREATE TABLE IF NOT EXISTS pathways (id INTEGER PRIMARY KEY AUTOINCREMENT,
                                    name TEXT,
                                    description TEXT)""")
c.execute("""CREATE TABLE IF NOT EXISTS enzymes (id INTEGER PRIMARY KEY AUTOINCREMENT,
                                    name TEXT,
                                    function TEXT,
                                    ec_num INT)""")
conn.commit()

# %%
from abwse import abwse
pathways = ['glycolysis', 'TCA cycle', 'pentose phosphata']
species = ['Drosophila melanogaster', 'Escherichia coli', 'Homo sapiens']
enzymes = ['Hexokinase', 'Glucose-6-phosphate isomerase', 'Triosephosphate isomerase', 'Fructose-bisphosphate aldolase',\
          'Citrate synthase', 'Aconitase', 'Isocitrate dehydrogenase', 'α-Ketoglutarate dehydrogenase',\
          'glucose 6-phosphate dehydrogenase', '6-phosphogluconolactonase', '6-phosphogluconate dehydrogenase', 'Ribose-5-phosphate isomerase']
for spe in species :
    for enz in enzymes:
        enzyme_info = abwse.ezsearch(enz, spe, 'rainl199922@berkeley.edu', rettype='dict')
        print(abwse.eztable(enzyme_info, 100))
# Out:
# +--------------+---------------+----------------------+--------------------+-----------------------+
# |     name     |  enzyme_name  |       species        |       start        |          end          |
# +--------------+---------------+----------------------+--------------------+-----------------------+
# |    Hex-A     |  Hexokinase A | Drosophila melanogas |      9585675       |        9589813        |
# |              |               |   ter (fruit fly)    |                    |                       |
# +--------------+---------------+----------------------+--------------------+-----------------------+
# | description  |  chromosome   |          EC          |       nt_seq       |       tran_seq        |
# +--------------+---------------+----------------------+--------------------+-----------------------+
# | Hexokinase A |       X       |       2.7.1.1        | ATGCCATTTGTGGACCCC | 3 types; MDRELNGAMKSV |
# |              |               |                      |  TCAGCGTCGCAC...   |   SINSAQLNGHNNG...    |
# +--------------+---------------+----------------------+--------------------+-----------------------+
# +---------------+---------------+---------------------+--------------------+----------------------+
# |     name      |  enzyme_name  |       species       |       start        |         end          |
# +---------------+---------------+---------------------+--------------------+----------------------+
# |      Pgi      |  Phosphogluco | Drosophila melanoga |      8910900       |       8914069        |
# |               | se isomerase  |  ster (fruit fly)   |                    |                      |
# +---------------+---------------+---------------------+--------------------+----------------------+
# |  description  |  chromosome   |         EC          |       nt_seq       |       tran_seq       |
# +---------------+---------------+---------------------+--------------------+----------------------+
# | Phosphoglucos |      2R       |       5.3.1.9       | ACATCGAATTCATAAATT | 3 types; MAGPLPPLNQE |
# |  e isomerase  |               |                     |  TTTATTTACGGT...   |  AAFQKLQEYYDSKG...   |
# +---------------+---------------+---------------------+--------------------+----------------------+
# +----------------+----------------+---------------------+--------------------+----------------------+
# |      name      |  enzyme_name   |       species       |       start        |         end          |
# +----------------+----------------+---------------------+--------------------+----------------------+
# |      Tpi       |  Triose phosph | Drosophila melanoga |      30132981      |       30134599       |
# |                | ate isomerase  |  ster (fruit fly)   |                    |                      |
# +----------------+----------------+---------------------+--------------------+----------------------+
# |  description   |   chromosome   |         EC          |       nt_seq       |       tran_seq       |
# +----------------+----------------+---------------------+--------------------+----------------------+
# | Triose phospha |       3R       |       5.-.-.-       | GGTATATAAGTAAATGAG | 3 types; MPPGVLNDLNR |
# |  te isomerase  |                |                     |  TAGCGCATAATT...   |  NGIQCIASVTLLQR...   |
# +----------------+----------------+---------------------+--------------------+----------------------+
# +-------------+-------------+----------------------+---------------------+------------------------+
# |    name     | enzyme_name |       species        |        start        |          end           |
# +-------------+-------------+----------------------+---------------------+------------------------+
# |     Ald     |   Aldolase  | Drosophila melanogas |      26254069       |        26261591        |
# |             |             |   ter (fruit fly)    |                     |                        |
# +-------------+-------------+----------------------+---------------------+------------------------+
# | description | chromosome  |          EC          |       nt_seq        |        tran_seq        |
# +-------------+-------------+----------------------+---------------------+------------------------+
# |  Aldolase   |     3R      |       4.1.2.13       | GGGTTTCTTTGCTCTTAAG | 10 types; MTTYFNYPSKEL |
# |             |             |                      |   GTTTTTTATTG...    |    QDELREIAQKIVA...    |
# +-------------+-------------+----------------------+---------------------+------------------------+
# +-------------+-------------+-----------------------+---------------------+------------------------+
# |    name     | enzyme_name |        species        |        start        |          end           |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# |     kdn     |  knockdown  | Drosophila melanogast |       6350629       |        6361323         |
# |             |             |    er (fruit fly)     |                     |                        |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# | description | chromosome  |          EC           |       nt_seq        |        tran_seq        |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# |  knockdown  |      X      |        2.3.3.1        | AATAAATTTTTGTATCCTA | 2 types; MFVRRFGNGSLGH |
# |             |             |                       |   CATCACTAGCT...    |    HFAFQRRYLAKN...     |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# +-------------+-------------+-----------------------+---------------------+------------------------+
# |    name     | enzyme_name |        species        |        start        |          end           |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# |    Acon     |  Aconitase  | Drosophila melanogast |      21168570       |        21173185        |
# |             |             |    er (fruit fly)     |                     |                        |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# | description | chromosome  |          EC           |       nt_seq        |        tran_seq        |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# |  Aconitase  |     2L      |        4.2.1.3        | AATTTTGGCGGGAAACAAG | 4 types; MAARLMNAQAQVC |
# |             |             |                       |   CCGGCGGAACA...    |    RLGKHVASEATV...     |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# +---------------+---------------+---------------------+--------------------+----------------------+
# |     name      |  enzyme_name  |       species       |       start        |         end          |
# +---------------+---------------+---------------------+--------------------+----------------------+
# |      Idh      |  Isocitrate d | Drosophila melanoga |      8356404       |       8360906        |
# |               | ehydrogenase  |  ster (fruit fly)   |                    |                      |
# +---------------+---------------+---------------------+--------------------+----------------------+
# |  description  |  chromosome   |         EC          |       nt_seq       |       tran_seq       |
# +---------------+---------------+---------------------+--------------------+----------------------+
# | Isocitrate de |      3L       |      1.1.1.42       | CCGGTATAAAAATACATT | 9 types; MFALRRTAAMM |
# |  hydrogenase  |               |                     |  TATTTGAAATTT...   |  TSVHRQPHLSQAVF...   |
# +---------------+---------------+---------------------+--------------------+----------------------+
# +-------------+---------------+----------------------+---------------------+-----------------------+
# |    name     |  enzyme_name  |       species        |        start        |          end          |
# +-------------+---------------+----------------------+---------------------+-----------------------+
# |   CG7430    |  uncharacteri | Drosophila melanogas |      17846916       |       17849601        |
# |             |  zed protein  |   ter (fruit fly)    |                     |                       |
# +-------------+---------------+----------------------+---------------------+-----------------------+
# | description |  chromosome   |          EC          |       nt_seq        |       tran_seq        |
# +-------------+---------------+----------------------+---------------------+-----------------------+
# |    None     |      3L       |       1.8.1.4        | TGACGGACATATCGTATTT | 2 types; MQFTLRHVVSAV |
# |             |               |                      |   TGAACGATCAT...    |   AKTPLRTNAAILG...    |
# +-------------+---------------+----------------------+---------------------+-----------------------+
# +-----------------+------------------+--------------------+-------------------+---------------------+
# |      name       |   enzyme_name    |      species       |       start       |         end         |
# +-----------------+------------------+--------------------+-------------------+---------------------+
# |       Zw        |  Zwischenferment | Drosophila melanog |     19667252      |      19672353       |
# |                 |                  | aster (fruit fly)  |                   |                     |
# +-----------------+------------------+--------------------+-------------------+---------------------+
# |   description   |    chromosome    |         EC         |      nt_seq       |      tran_seq       |
# +-----------------+------------------+--------------------+-------------------+---------------------+
# | Zwischenferment |        X         |      1.1.1.49      | GGCGTTTGTTTGCTGCG | 3 types; MATQKEDHTA |
# |                 |                  |                    | GCGGTTCGCGCCG...  | LDLIIKSLKSPTMVC...  |
# +-----------------+------------------+--------------------+-------------------+---------------------+
# +-------------+-------------+-----------------------+---------------------+------------------------+
# |    name     | enzyme_name |        species        |        start        |          end           |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# |  Oscillin   |   oscillin  | Drosophila melanogast |       5547086       |        5549614         |
# |             |             |    er (fruit fly)     |                     |                        |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# | description | chromosome  |          EC           |       nt_seq        |        tran_seq        |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# |    None     |     2L      |       3.5.99.6        | ACGCGAGAGATGCGGTTAA | 8 types; MRLVILETSDSVG |
# |             |             |                       |   AGTTCGTTCAA...    |    KWAAKYVMKRIN...     |
# +-------------+-------------+-----------------------+---------------------+------------------------+
# +------------------+-----------------+-------------------+------------------+--------------------+
# |       name       |   enzyme_name   |      species      |      start       |        end         |
# +------------------+-----------------+-------------------+------------------+--------------------+
# |       Pgd        |  Phosphoglucona | Drosophila melano |     2145136      |      2148566       |
# |                  | te dehydrogenas | gaster (fruit fly |                  |                    |
# |                  |        e        |         )         |                  |                    |
# +------------------+-----------------+-------------------+------------------+--------------------+
# |   description    |   chromosome    |        EC         |      nt_seq      |      tran_seq      |
# +------------------+-----------------+-------------------+------------------+--------------------+
# | Phosphogluconate |        X        |     1.1.1.44      | AGTAGCAGTACTCATT | 2 types; MSGQADIAL |
# |  dehydrogenase.. |                 |                   | AGAGTCCACTCACA.. | IGLAVMGQNLILNMDE.. |
# |        .         |                 |                   |        .         |         .          |
# +------------------+-----------------+-------------------+------------------+--------------------+
# +----------------+-----------------+--------------------+-------------------+---------------------+
# |      name      |   enzyme_name   |      species       |       start       |         end         |
# +----------------+-----------------+--------------------+-------------------+---------------------+
# |      Rpi       |  Ribose-5-phosp | Drosophila melanog |     23355183      |      23356441       |
# |                | hate isomerase  | aster (fruit fly)  |                   |                     |
# +----------------+-----------------+--------------------+-------------------+---------------------+
# |  description   |   chromosome    |         EC         |      nt_seq       |      tran_seq       |
# +----------------+-----------------+--------------------+-------------------+---------------------+
# | Ribose-5-phosp |       2R        |      5.3.1.6       | CGGCTTGATCTCTGTGA | 2 types; MDDIALDAAK |
# | hate isomerase |                 |                    | CATTGAAGTTGCG...  | KTAARTAVDQWVTED...  |
# +----------------+-----------------+--------------------+-------------------+---------------------+
# +-------------------+-------------+-----------------------+-------------------+---------------------+
# |       name        | enzyme_name |        species        |       start       |         end         |
# +-------------------+-------------+-----------------------+-------------------+---------------------+
# |        mak        |   kinase    | Escherichia coli str. |      410144       |       411052        |
# |                   |             |  K-12 substr. MG1655  |                   |                     |
# +-------------------+-------------+-----------------------+-------------------+---------------------+
# |    description    | chromosome  |          EC           |      nt_seq       |      tran_seq       |
# +-------------------+-------------+-----------------------+-------------------+---------------------+
# | putative regulato |    None     |        2.7.1.4        | GTGCGTATAGGTATCGA | 1 types; MRIGIDLGGT |
# | r; Not classi...  |             |                       | TTTAGGCGGCACC...  | KTEVIALGDAGEQLY...  |
# +-------------------+-------------+-----------------------+-------------------+---------------------+
# +-------------+-----------------+----------------------+--------------------+----------------------+
# |    name     |   enzyme_name   |       species        |       start        |         end          |
# +-------------+-----------------+----------------------+--------------------+----------------------+
# |     pgi     | glucose-6-phosp | Escherichia coli O83 |      4289297       |       4290946        |
# |             | hate isomerase  |  :H1 str. NRG 857C   |                    |                      |
# +-------------+-----------------+----------------------+--------------------+----------------------+
# | description |   chromosome    |          EC          |       nt_seq       |       tran_seq       |
# +-------------+-----------------+----------------------+--------------------+----------------------+
# |    None     |      None       |       5.3.1.9        | ATGAAAAACATCAATCCA | 1 types; MKNINPTQTAA |
# |             |                 |                      |  ACGCAGACCGCT...   |  WQALQKHFDEMKDV...   |
# +-------------+-----------------+----------------------+--------------------+----------------------+
# +------------------+--------------+-----------------------+------------------+--------------------+
# |       name       | enzyme_name  |        species        |      start       |        end         |
# +------------------+--------------+-----------------------+------------------+--------------------+
# |       tpiA       | triosephosph | Escherichia coli str. |     4110740      |      4111507       |
# |                  | ate isomeras |  K-12 substr. MG1655  |                  |                    |
# |                  |      e       |                       |                  |                    |
# +------------------+--------------+-----------------------+------------------+--------------------+
# |   description    |  chromosome  |          EC           |      nt_seq      |      tran_seq      |
# +------------------+--------------+-----------------------+------------------+--------------------+
# | enzyme; Energy m |     None     |        5.3.1.1        | TTAAGCCTGTTTAGCC | 1 types; MRHPLVMGN |
# | etabolism, car.. |              |                       | GCTTCTGCAGCTTT.. | WKLNGSRHMVHELVSN.. |
# |        .         |              |                       |        .         |         .          |
# +------------------+--------------+-----------------------+------------------+--------------------+
# +-------------------+-------------+-----------------------+-------------------+---------------------+
# |       name        | enzyme_name |        species        |       start       |         end         |
# +-------------------+-------------+-----------------------+-------------------+---------------------+
# |       fbaA        |   class II  | Escherichia coli str. |      3070165      |       3071244       |
# |                   |             |  K-12 substr. MG1655  |                   |                     |
# +-------------------+-------------+-----------------------+-------------------+---------------------+
# |    description    | chromosome  |          EC           |      nt_seq       |      tran_seq       |
# +-------------------+-------------+-----------------------+-------------------+---------------------+
# | enzyme; Energy me |    None     |       4.1.2.13        | TTACAGAACGTCGATCG | 1 types; MSKIFDFVKP |
# | tabolism, car...  |             |                       | CGTTCAGTTCCTG...  | GVITGDDVQKVFQVA...  |
# +-------------------+-------------+-----------------------+-------------------+---------------------+
# +------------------+------------------+----------------------+------------------+--------------------+
# |       name       |   enzyme_name    |       species        |      start       |        end         |
# +------------------+------------------+----------------------+------------------+--------------------+
# |       gltA       | citrate synthase | Escherichia coli str |      753185      |       754468       |
# |                  |                  | . K-12 substr. MG165 |                  |                    |
# |                  |                  |          5           |                  |                    |
# +------------------+------------------+----------------------+------------------+--------------------+
# |   description    |    chromosome    |          EC          |      nt_seq      |      tran_seq      |
# +------------------+------------------+----------------------+------------------+--------------------+
# | enzyme; Energy m |       None       |       2.3.3.1        | TTAACGCTTGATATCG | 1 types; MADTKAKLT |
# | etabolism, car.. |                  |                      | CTTTTAAAGTCGCG.. | LNGDTAVELDVLKGTL.. |
# |        .         |                  |                      |        .         |         .          |
# +------------------+------------------+----------------------+------------------+--------------------+
# +------------------+--------------+-----------------------+------------------+---------------------+
# |       name       | enzyme_name  |        species        |      start       |         end         |
# +------------------+--------------+-----------------------+------------------+---------------------+
# |       acnA       |  aconitase A | Escherichia coli str. |     1335831      |       1338506       |
# |                  |              |  K-12 substr. MG1655  |                  |                     |
# +------------------+--------------+-----------------------+------------------+---------------------+
# |   description    |  chromosome  |          EC           |      nt_seq      |      tran_seq       |
# +------------------+--------------+-----------------------+------------------+---------------------+
# | enzyme; Energy m |     None     |        4.2.1.3        | ATGTCGTCAACCCTAC | 1 types; MSSTLREASK |
# | etabolism, car.. |              |                       | GAGAAGCCAGTAAG.. | DTLQAKDKTYHYYSL...  |
# |        .         |              |                       |        .         |                     |
# +------------------+--------------+-----------------------+------------------+---------------------+
# +-------------------+------------+-----------------------+-------------------+---------------------+
# |       name        | enzyme_nam |        species        |       start       |         end         |
# |                   |     e      |                       |                   |                     |
# +-------------------+------------+-----------------------+-------------------+---------------------+
# |        icd        |  tellurite | Escherichia coli str. |      1195123      |       1196373       |
# |                   |  reductase |  K-12 substr. MG1655  |                   |                     |
# +-------------------+------------+-----------------------+-------------------+---------------------+
# |    description    | chromosome |          EC           |      nt_seq       |      tran_seq       |
# +-------------------+------------+-----------------------+-------------------+---------------------+
# | enzyme; Energy me |    None    |       1.1.1.42        | ATGGAAAGTAAAGTAGT | 1 types; MESKVVVPAQ |
# | tabolism, car...  |            |                       | TGTTCCGGCACAA...  | GKKITLQNGKLNVPE...  |
# +-------------------+------------+-----------------------+-------------------+---------------------+
# +-------------+-------------+-------------------------+--------------------+-----------------------+
# |    name     | enzyme_name |         species         |       start        |          end          |
# +-------------+-------------+-------------------------+--------------------+-----------------------+
# |    cobB     |  chemotaxis | Escherichia coli str. K |      1179631       |        1180359        |
# |             |  regulator  |   -12 substr. MG1655    |                    |                       |
# +-------------+-------------+-------------------------+--------------------+-----------------------+
# | description | chromosome  |           EC            |       nt_seq       |       tran_seq        |
# +-------------+-------------+-------------------------+--------------------+-----------------------+
# |    None     |    None     |          None           | ATGGAAAAACCAAGAGTA | 1 types; MEKPRVLVLTGA |
# |             |             |                         |  CTCGTACTGACA...   |   GISAESGIRTFRA...    |
# +-------------+-------------+-------------------------+--------------------+-----------------------+
# +--------------+---------------------+---------------+---------------------+-----------------------+
# |     name     |     enzyme_name     |    species    |        start        |          end          |
# +--------------+---------------------+---------------+---------------------+-----------------------+
# |     zwf      | glucose-6-phosphate | Escherichia c |       2170031       |        2171506        |
# |              |    dehydrogenase    |  oli UMN026   |                     |                       |
# +--------------+---------------------+---------------+---------------------+-----------------------+
# | description  |     chromosome      |      EC       |       nt_seq        |       tran_seq        |
# +--------------+---------------------+---------------+---------------------+-----------------------+
# | 6.6 : Entner |        None         |   1.1.1.49    | TTACTCAAACTCATTCCAG | 1 types; MAVTQTAQACDL |
# |  -Doudoroff  |                     |               |   GAACGACCATC...    |   VIFGAKGDLARRK...    |
# +--------------+---------------------+---------------+---------------------+-----------------------+
# +------------+---------------+------------------------+--------------------+----------------------+
# |    name    |  enzyme_name  |        species         |       start        |         end          |
# +------------+---------------+------------------------+--------------------+----------------------+
# |    pgl     | 6-phosphogluc | Escherichia coli str.  |       798586       |        799581        |
# |            | onolactonase  |  K-12 substr. MG1655   |                    |                      |
# +------------+---------------+------------------------+--------------------+----------------------+
# | descriptio |  chromosome   |           EC           |       nt_seq       |       tran_seq       |
# |     n      |               |                        |                    |                      |
# +------------+---------------+------------------------+--------------------+----------------------+
# | orf; Not c |     None      |        3.1.1.31        | ATGAAGCAAACAGTTTAT | 1 types; MKQTVYIASPE |
# | lassified  |               |                        |  ATCGCCAGCCCT...   |  SQQIHVWNLNHEGA...   |
# +------------+---------------+------------------------+--------------------+----------------------+
# +------------------+------------------+----------------------+------------------+--------------------+
# |       name       |   enzyme_name    |       species        |      start       |        end         |
# +------------------+------------------+----------------------+------------------+--------------------+
# |       gnd        |  decarboxylating | Escherichia coli str |     2099862      |      2101268       |
# |                  |                  | . K-12 substr. MG165 |                  |                    |
# |                  |                  |          5           |                  |                    |
# +------------------+------------------+----------------------+------------------+--------------------+
# |   description    |    chromosome    |          EC          |      nt_seq      |      tran_seq      |
# +------------------+------------------+----------------------+------------------+--------------------+
# | enzyme; Energy m |       None       |       1.1.1.44       | TTAATCCAGCCATTCG | 1 types; MSKQQIGVV |
# | etabolism, car.. |                  |                      | GTATGGAACACACC.. | GMAVMGRNLALNIESR.. |
# |        .         |                  |                      |        .         |         .          |
# +------------------+------------------+----------------------+------------------+--------------------+
# +------------------+---------------+----------------------+------------------+--------------------+
# |       name       |  enzyme_name  |       species        |      start       |        end         |
# +------------------+---------------+----------------------+------------------+--------------------+
# |       rpiB       | allose 6-phos | Escherichia coli str |     4313350      |      4313799       |
# |                  | phate isomera | . K-12 substr. MG165 |                  |                    |
# |                  |      se       |          5           |                  |                    |
# +------------------+---------------+----------------------+------------------+--------------------+
# |   description    |  chromosome   |          EC          |      nt_seq      |      tran_seq      |
# +------------------+---------------+----------------------+------------------+--------------------+
# | enzyme; Central  |     None      |       5.3.1.6        | ATGAAAAAGATTGCAT | 1 types; MKKIAFGCD |
# | intermediary m.. |               |                      | TTGGCTGTGATCAT.. | HVGFILKHEIVAHLVE.. |
# |        .         |               |                      |        .         |         .          |
# +------------------+---------------+----------------------+------------------+--------------------+
# +---------------------+---------------+-------------+---------------------+------------------------+
# |        name         |  enzyme_name  |   species   |        start        |          end           |
# +---------------------+---------------+-------------+---------------------+------------------------+
# |         HK1         |  hexokinase 1 | Homo sapien |      69269991       |        69401882        |
# |                     |               |  s (human)  |                     |                        |
# +---------------------+---------------+-------------+---------------------+------------------------+
# |     description     |  chromosome   |     EC      |       nt_seq        |        tran_seq        |
# +---------------------+---------------+-------------+---------------------+------------------------+
# | hexokinase 1; Deriv |      10       |    None     | CAGAGAGGGAAAACATCTA | 13 types; MGQICQRESRQG |
# |   ed by autom...    |               |             |   TCTTGCTGTGT...    |    LAMLPRLFLNPWR...    |
# +---------------------+---------------+-------------+---------------------+------------------------+
# +--------------------+------------------+-------------+--------------------+----------------------+
# |        name        |   enzyme_name    |   species   |       start        |         end          |
# +--------------------+------------------+-------------+--------------------+----------------------+
# |        GPI         |  glucose-6-phosp | Homo sapien |      34353330      |       34402413       |
# |                    |  hate isomerase  |  s (human)  |                    |                      |
# +--------------------+------------------+-------------+--------------------+----------------------+
# |    description     |    chromosome    |     EC      |       nt_seq       |       tran_seq       |
# +--------------------+------------------+-------------+--------------------+----------------------+
# | KIAA0355; Derived  |        19        |    None     | AGCTGAGGGCATAACTGA | 8 types; MVALCSLQHLG |
# |  by automated...   |                  |             |  CCATTTTTTGGA...   |  SSDPRALPTLPTAT...   |
# +--------------------+------------------+-------------+--------------------+----------------------+
# +--------------------+------------------+-------------+--------------------+-----------------------+
# |        name        |   enzyme_name    |   species   |       start        |          end          |
# +--------------------+------------------+-------------+--------------------+-----------------------+
# |        TPI1        |  triosephosphate | Homo sapien |      6866834       |        6870946        |
# |                    |    isomerase 1   |  s (human)  |                    |                       |
# +--------------------+------------------+-------------+--------------------+-----------------------+
# |    description     |    chromosome    |     EC      |       nt_seq       |       tran_seq        |
# +--------------------+------------------+-------------+--------------------+-----------------------+
# | triosephosphate is |        12        |    None     | ATGGAGTGAAGAACCCTT | 3 types; MAEDGEEAEFHF |
# |  omerase 1; D...   |                  |             |  CCCTCTCTTTAT...   |   AALYISGQWPRLR...    |
# +--------------------+------------------+-------------+--------------------+-----------------------+
# +---------------------+---------------+-------------+---------------------+------------------------+
# |        name         |  enzyme_name  |   species   |        start        |          end           |
# +---------------------+---------------+-------------+---------------------+------------------------+
# |        ALDOA        |  fructose-bis | Homo sapien |      30053090       |        30070420        |
# |                     |  phosphate A  |  s (human)  |                     |                        |
# +---------------------+---------------+-------------+---------------------+------------------------+
# |     description     |  chromosome   |     EC      |       nt_seq        |        tran_seq        |
# +---------------------+---------------+-------------+---------------------+------------------------+
# | aldolase, fructose- |      16       |    None     | AAACACCGCTCTGGTCACC | 11 types; MARRKPEGSSFN |
# |   bisphosphat...    |               |             |   ATGGCAACAGC...    |    MTHLSMAMAFSFP...    |
# +---------------------+---------------+-------------+---------------------+------------------------+
# +----------------------+------------+--------------+----------------------+------------------------+
# |         name         | enzyme_nam |   species    |        start         |          end           |
# |                      |     e      |              |                      |                        |
# +----------------------+------------+--------------+----------------------+------------------------+
# |          CS          |  citrate s | Homo sapiens |       56271699       |        56300391        |
# |                      |  ynthase   |    (human)   |                      |                        |
# +----------------------+------------+--------------+----------------------+------------------------+
# |     description      | chromosome |      EC      |        nt_seq        |        tran_seq        |
# +----------------------+------------+--------------+----------------------+------------------------+
# | citrate synthase; De |     12     |     None     | CATTGTTAATAAAAACATTT | 1 types; MALLTAAARLLGT |
# |    rived by a...     |            |              |    ATTTTGCATT...     |    KNASCLVLAARH...     |
# +----------------------+------------+--------------+----------------------+------------------------+
# +---------------------+--------------+-------------+---------------------+------------------------+
# |        name         | enzyme_name  |   species   |        start        |          end           |
# +---------------------+--------------+-------------+---------------------+------------------------+
# |        ACO1         |  aconitase 1 | Homo sapien |      32384603       |        32450836        |
# |                     |              |  s (human)  |                     |                        |
# +---------------------+--------------+-------------+---------------------+------------------------+
# |     description     |  chromosome  |     EC      |       nt_seq        |        tran_seq        |
# +---------------------+--------------+-------------+---------------------+------------------------+
# | aconitase 1; Derive |      9       |    None     | ATCGCGCGGCGGCCCCGGG | 4 types; MSNPFAHLAEPLD |
# |   d by automa...    |              |             |   GGCGAGAGGGG...    |    PVQPGKKFFNLN...     |
# +---------------------+--------------+-------------+---------------------+------------------------+
# +----------------------+-------------+--------------+----------------------+------------------------+
# |         name         | enzyme_name |   species    |        start         |          end           |
# +----------------------+-------------+--------------+----------------------+------------------------+
# |         IDH1         |  cytosolic  | Homo sapiens |      208236227       |       208255143        |
# |                      |             |    (human)   |                      |                        |
# +----------------------+-------------+--------------+----------------------+------------------------+
# |     description      | chromosome  |      EC      |        nt_seq        |        tran_seq        |
# +----------------------+-------------+--------------+----------------------+------------------------+
# | isocitrate dehydroge |      2      |     None     | AATGGTAATTAGCACTTAAT | 3 types; MSKKISGGSVVEM |
# |    nase (NADP...     |             |              |    TTTAATTAAA...     |    QGDEMTRIIWEL...     |
# +----------------------+-------------+--------------+----------------------+------------------------+
# +---------------------+-----------------+-------------+---------------------+-----------------------+
# |        name         |   enzyme_name   |   species   |        start        |          end          |
# +---------------------+-----------------+-------------+---------------------+-----------------------+
# |        OGDH         |  oxoglutarate d | Homo sapien |      44606522       |       44709070        |
# |                     |  ehydrogenase   |  s (human)  |                     |                       |
# +---------------------+-----------------+-------------+---------------------+-----------------------+
# |     description     |   chromosome    |     EC      |       nt_seq        |       tran_seq        |
# +---------------------+-----------------+-------------+---------------------+-----------------------+
# | oxoglutarate dehydr |        7        |    None     | TGTAAGAGGGGAGGGCATT | 7 types; MFHLRTCAAKLR |
# |   ogenase; De...    |                 |             |   CTTCTCCAGGG...    |   PLTASQTVKTFSQ...    |
# +---------------------+-----------------+-------------+---------------------+-----------------------+
# +--------------------+--------------------+------------+--------------------+----------------------+
# |        name        |    enzyme_name     |  species   |       start        |         end          |
# +--------------------+--------------------+------------+--------------------+----------------------+
# |        G6PD        |  glucose-6-phospha | Homo sapie |     154531390      |      154547586       |
# |                    |  te dehydrogenase  | ns (human) |                    |                      |
# +--------------------+--------------------+------------+--------------------+----------------------+
# |    description     |     chromosome     |     EC     |       nt_seq       |       tran_seq       |
# +--------------------+--------------------+------------+--------------------+----------------------+
# | glucose-6-phosphat |         X          |    None    | GGGCTGTTTGCGGATTTA | 4 types; MGRRGSAPGNG |
# |  e dehydrogen...   |                    |            |  ATGGCAGGGCAT...   |  RTLRGCERGGRRRR...   |
# +--------------------+--------------------+------------+--------------------+----------------------+
# +---------------------+---------------+-------------+---------------------+------------------------+
# |        name         |  enzyme_name  |   species   |        start        |          end           |
# +---------------------+---------------+-------------+---------------------+------------------------+
# |        H6PD         | glucose 1-deh | Homo sapien |       9234767       |        9271337         |
# |                     |  ydrogenase   |  s (human)  |                     |                        |
# +---------------------+---------------+-------------+---------------------+------------------------+
# |     description     |  chromosome   |     EC      |       nt_seq        |        tran_seq        |
# +---------------------+---------------+-------------+---------------------+------------------------+
# | hexose-6-phosphate  |       1       |    None     | GGGCCCCAGTCTTGCTGAG | 6 types; MLAEPFNWHPGMW |
# |   dehydrogena...    |               |             |   CGCAAGGCGGT...    |    NMLIVAMCLALL...     |
# +---------------------+---------------+-------------+---------------------+------------------------+
# +----------------------+-------------+--------------+----------------------+------------------------+
# |         name         | enzyme_name |   species    |        start         |          end           |
# +----------------------+-------------+--------------+----------------------+------------------------+
# |        STK11         | threonine k | Homo sapiens |       1205799        |        1228435         |
# |                      |  inase 11   |    (human)   |                      |                        |
# +----------------------+-------------+--------------+----------------------+------------------------+
# |     description      | chromosome  |      EC      |        nt_seq        |        tran_seq        |
# +----------------------+-------------+--------------+----------------------+------------------------+
# | serine/threonine kin |     19      |     None     | GCGTGTCGGGCGCGGAAGGG | 4 types; MEVVDPQQLGMFT |
# |    ase 11; De...     |             |              |    GGAGGCGGCC...     |    EGELMSVGMDTF...     |
# +----------------------+-------------+--------------+----------------------+------------------------+
# +--------------------+-------------------+-------------+--------------------+----------------------+
# |        name        |    enzyme_name    |   species   |       start        |         end          |
# +--------------------+-------------------+-------------+--------------------+----------------------+
# |        RPIA        |  ribose 5-phospha | Homo sapien |      88691658      |       88750935       |
# |                    |  te isomerase A   |  s (human)  |                    |                      |
# +--------------------+-------------------+-------------+--------------------+----------------------+
# |    description     |    chromosome     |     EC      |       nt_seq       |       tran_seq       |
# +--------------------+-------------------+-------------+--------------------+----------------------+
# | ribose 5-phosphate |         2         |    None     | CGGGGGCGGGACTTCAGC | 1 types; MQRPGPFSTLY |
# |   isomerase A...   |                   |             |  GGAGGCCGGAGC...   |  GRVLAPLPGRAGGA...   |
# +--------------------+-------------------+-------------+--------------------+----------------------+

# %%
from abwse import abwse
pathways = ['glycolysis', 'TCA cycle', 'pentose phosphata']
species = ['Drosophila melanogaster', 'Escherichia coli', 'Homo sapiens']
enzymes = ['1.1.1.27', '6.2.1.1', '5.4.2.2', '1.1.1.1']
for spe in species :
    for enz in enzymes:
        enzyme_info = abwse.ezsearch(enz, spe, 'rainl199922@berkeley.edu', rettype='dict')
        print(abwse.eztable(enzyme_info, 100))
# Out:
# +----------------+----------------+---------------------+--------------------+----------------------+
# |      name      |  enzyme_name   |       species       |       start        |         end          |
# +----------------+----------------+---------------------+--------------------+----------------------+
# |     ImpL3      |  Ecdysone-indu | Drosophila melanoga |      6259105       |       6262694        |
# |                | cible gene L3  |  ster (fruit fly)   |                    |                      |
# +----------------+----------------+---------------------+--------------------+----------------------+
# |  description   |   chromosome   |         EC          |       nt_seq       |       tran_seq       |
# +----------------+----------------+---------------------+--------------------+----------------------+
# | Ecdysone-induc |       3L       |      1.1.1.27       | ATCTAGTTTTTTGATGGG | 4 types; MAAIKDSLLAQ |
# |  ible gene L3  |                |                     |  TGCTCGAAACCA...   |  VAEVLPSSGHKVTI...   |
# +----------------+----------------+---------------------+--------------------+----------------------+
# +----------------+----------------+---------------------+--------------------+----------------------+
# |      name      |  enzyme_name   |       species       |       start        |         end          |
# +----------------+----------------+---------------------+--------------------+----------------------+
# |     AcCoAS     |  Acetyl Coenzy | Drosophila melanoga |      21270722      |       21280243       |
# |                | me A synthase  |  ster (fruit fly)   |                    |                      |
# +----------------+----------------+---------------------+--------------------+----------------------+
# |  description   |   chromosome   |         EC          |       nt_seq       |       tran_seq       |
# +----------------+----------------+---------------------+--------------------+----------------------+
# | Acetyl Coenzym |       3L       |       6.2.1.1       | ATTTATAGATATGTAAAT | 3 types; MPAEKSIYDPN |
# |  e A synthase  |                |                     |  TGCAATCTTTCG...   |  PAISQNAYISSFEE...   |
# +----------------+----------------+---------------------+--------------------+----------------------+
# +--------------+--------------+----------------------+---------------------+-----------------------+
# |     name     | enzyme_name  |       species        |        start        |          end          |
# +--------------+--------------+----------------------+---------------------+-----------------------+
# |     Pgm      |  phosphogluc | Drosophila melanogas |      16126018       |       16128531        |
# |              |  ose mutase  |   ter (fruit fly)    |                     |                       |
# +--------------+--------------+----------------------+---------------------+-----------------------+
# | description  |  chromosome  |          EC          |       nt_seq        |       tran_seq        |
# +--------------+--------------+----------------------+---------------------+-----------------------+
# | phosphogluco |      3L      |       5.4.2.2        | GGGCTACACAAACTTTAAT | 1 types; MSLTVEIVATKP |
# |  se mutase   |              |                      |   AAATCCGAAAC...    |   YEGQKPGTSGLRK...    |
# +--------------+--------------+----------------------+---------------------+-----------------------+
# +-------------+--------------+----------------------+---------------------+-----------------------+
# |    name     | enzyme_name  |       species        |        start        |          end          |
# +-------------+--------------+----------------------+---------------------+-----------------------+
# |     Adh     |  Alcohol deh | Drosophila melanogas |      14615552       |       14618902        |
# |             |  ydrogenase  |   ter (fruit fly)    |                     |                       |
# +-------------+--------------+----------------------+---------------------+-----------------------+
# | description |  chromosome  |          EC          |       nt_seq        |       tran_seq        |
# +-------------+--------------+----------------------+---------------------+-----------------------+
# |  outspread  |      2L      |       1.1.1.1        | CATGCATTATTGTCTCAGT | 8 types; MSFTLTNKNVIF |
# |             |              |                      |   GCAGTTGTCAG...    |   VAGLGGIGLDTSK...    |
# +-------------+--------------+----------------------+---------------------+-----------------------+
# +-------------+----------------+----------------+-----------------------+--------------------------+
# |    name     |  enzyme_name   |    species     |         start         |           end            |
# +-------------+----------------+----------------+-----------------------+--------------------------+
# |     ldh     | L-lactate dehy | Escherichia co |        4606585        |         4607658          |
# |             |   drogenase    |    li PMV-1    |                       |                          |
# +-------------+----------------+----------------+-----------------------+--------------------------+
# | description |   chromosome   |       EC       |        nt_seq         |         tran_seq         |
# +-------------+----------------+----------------+-----------------------+--------------------------+
# |    None     |      None      |      None      | ATGTCATTACAAATTGCTGTT | 2 types; MSLQIAVEKVRWLAA |
# |             |                |                |     GAAAAAGTG...      |      GLLELNGCDA...       |
# +-------------+----------------+----------------+-----------------------+--------------------------+
# +-------------------+------------+-----------------------+-------------------+---------------------+
# |       name        | enzyme_nam |        species        |       start       |         end         |
# |                   |     e      |                       |                   |                     |
# +-------------------+------------+-----------------------+-------------------+---------------------+
# |        acs        | acetyl-CoA | Escherichia coli str. |      4285413      |       4287371       |
# |                   |  synthetas |  K-12 substr. MG1655  |                   |                     |
# |                   |     e      |                       |                   |                     |
# +-------------------+------------+-----------------------+-------------------+---------------------+
# |    description    | chromosome |          EC           |      nt_seq       |      tran_seq       |
# +-------------------+------------+-----------------------+-------------------+---------------------+
# | enzyme; Fatty aci |    None    |        6.2.1.1        | TTACGATGGCATCGCGA | 1 types; MSQIHKHTIP |
# | d and phospha...  |            |                       | TAGCCTGCTTCTC...  | ANIADRCLINPQQYE...  |
# +-------------------+------------+-----------------------+-------------------+---------------------+
# +-------------------+-----------+------------------------+-------------------+---------------------+
# |       name        | enzyme_na |        species         |       start       |         end         |
# |                   |    me     |                        |                   |                     |
# +-------------------+-----------+------------------------+-------------------+---------------------+
# |        pgm        | phosphogl | Escherichia coli str.  |      713558       |       715198        |
# |                   | ucomutase |  K-12 substr. MG1655   |                   |                     |
# +-------------------+-----------+------------------------+-------------------+---------------------+
# |    description    | chromosom |           EC           |      nt_seq       |      tran_seq       |
# |                   |     e     |                        |                   |                     |
# +-------------------+-----------+------------------------+-------------------+---------------------+
# | enzyme; Degradati |   None    |        5.4.2.2         | ATGGCAATCCACAATCG | 1 types; MAIHNRAGQP |
# | on of small m...  |           |                        | TGCAGGCCAACCT...  | AQQSDLINVAQLTAQ...  |
# +-------------------+-----------+------------------------+-------------------+---------------------+
# +-------------+---------------+------------------+-----------------------+-------------------------+
# |    name     |  enzyme_name  |     species      |         start         |           end           |
# +-------------+---------------+------------------+-----------------------+-------------------------+
# | D616_p92049 | Alcohol dehyd | Escherichia coli |         27702         |          28751          |
# |             |   rogenase    |                  |                       |                         |
# +-------------+---------------+------------------+-----------------------+-------------------------+
# | description |  chromosome   |        EC        |        nt_seq         |        tran_seq         |
# +-------------+---------------+------------------+-----------------------+-------------------------+
# |    None     |     None      |     1.1.1.1      | ATGAAAACGGTTGGTTATGCC | 1 types; MKTVGYAAHSSDAK |
# |             |               |                  |     GCGCACTCT...      |     LVPWHFERRDL...      |
# +-------------+---------------+------------------+-----------------------+-------------------------+
# +---------------------+----------------+-------------+---------------------+-----------------------+
# |        name         |  enzyme_name   |   species   |        start        |          end          |
# +---------------------+----------------+-------------+---------------------+-----------------------+
# |        LDHA         |  lactate dehyd | Homo sapien |      18394389       |       18408218        |
# |                     |   rogenase A   |  s (human)  |                     |                       |
# +---------------------+----------------+-------------+---------------------+-----------------------+
# |     description     |   chromosome   |     EC      |       nt_seq        |       tran_seq        |
# +---------------------+----------------+-------------+---------------------+-----------------------+
# | lactate dehydrogena |       11       |    None     | GTCTGCCGGTCGGTTGTCT | 5 types; MGEPSGGYTYTQ |
# |   se A; Deriv...    |                |             |   GGCTGCGCGCG...    |   TSIFLFHAKIPFG...    |
# +---------------------+----------------+-------------+---------------------+-----------------------+
# +------------------+--------------------------+-----------+------------------+---------------------+
# |       name       |       enzyme_name        |  species  |      start       |         end         |
# +------------------+--------------------------+-----------+------------------+---------------------+
# |      ACSS2       |  acyl-CoA synthetase sho | Homo sapi |     34874942     |      34927966       |
# |                  | rt chain family member 2 | ens (huma |                  |                     |
# |                  |                          |    n)     |                  |                     |
# +------------------+--------------------------+-----------+------------------+---------------------+
# |   description    |        chromosome        |    EC     |      nt_seq      |      tran_seq       |
# +------------------+--------------------------+-----------+------------------+---------------------+
# | acyl-CoA synthet |            20            |   None    | AAAGTGCAGGGAAGTA | 13 types; MMVRWALLC |
# | ase short chai.. |                          |           | GCTGGGAAGGGAGG.. | EFWGDIAKEFYWKTPC... |
# |        .         |                          |           |        .         |                     |
# +------------------+--------------------------+-----------+------------------+---------------------+
# +---------------------+--------------+-------------+---------------------+------------------------+
# |        name         | enzyme_name  |   species   |        start        |          end           |
# +---------------------+--------------+-------------+---------------------+------------------------+
# |        PGM1         |  phosphogluc | Homo sapien |      63593276       |        63660245        |
# |                     |  omutase 1   |  s (human)  |                     |                        |
# +---------------------+--------------+-------------+---------------------+------------------------+
# |     description     |  chromosome  |     EC      |       nt_seq        |        tran_seq        |
# +---------------------+--------------+-------------+---------------------+------------------------+
# | phosphoglucomutase  |      1       |    None     | CCTTTCCCCTCCCGCCGGA | 3 types; MVKIVTVKTQAYQ |
# |   1; Derived ...    |              |             |   CCTGCCAGGAG...    |    DQKPGTSGLRKR...     |
# +---------------------+--------------+-------------+---------------------+------------------------+
# +--------------------+---------------------+------------+--------------------+----------------------+
# |        name        |     enzyme_name     |  species   |       start        |         end          |
# +--------------------+---------------------+------------+--------------------+----------------------+
# |       ADIPOQ       |  C1Q and collagen d | Homo sapie |     186842674      |      186858463       |
# |                    |  omain containing   | ns (human) |                    |                      |
# +--------------------+---------------------+------------+--------------------+----------------------+
# |    description     |     chromosome      |     EC     |       nt_seq       |       tran_seq       |
# +--------------------+---------------------+------------+--------------------+----------------------+
# | adiponectin, C1Q a |          3          |    None    | AGGCTGTTGAGGCTGGGC | 2 types; MLLLGAVLLLL |
# |  nd collagen ...   |                     |            |  CATCTCCTCCTC...   |  ALPGHDQETTTQGP...   |
# +--------------------+---------------------+------------+--------------------+----------------------+
